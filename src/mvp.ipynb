# %% [markdown]
# # Time series forecasting project

# %%
# Handle imports up-front
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from math import sqrt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from pmdarima import auto_arima

# %% [markdown]
# ## 1. Data loading

# %% [markdown]
# ### 1.1. Load

# %%
raw_data_df=sns.load_dataset("flights")

# %% [markdown]
# ### 1.2. Inspect

# %%
raw_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %% [markdown]
# ### 1.3. Encode date feature
#
# Pandas has many great tools to work with timeseries data - see the user guide article: '*[Time series / date functionality](https://pandas.pydata.org/docs/user_guide/timeseries.html)*'. First thing to do is convert our string date feature(s) to a Datetime object.

# %%
# Make a copy of the raw data to work with
timeseries_df=raw_data_df.copy()

# Extract the string month to a datetime object feature
timeseries_df['month']=pd.to_datetime(raw_data_df.month, format='%b').dt.month

# Use the month and year to create at 'date' datetime feature
timeseries_df['date']=pd.to_datetime(timeseries_df[['year', 'month']].assign(day=1))

# Set the datetime feature as the index
timeseries_df=timeseries_df.set_index('date')

# Keep only the passenger column
timeseries_df.drop(['year', 'month'], axis=1, inplace=True)

# Re-name 'passengers' to 'dependent_var' so we can easily swap datasets without making
# changes to the notebook
timeseries_df.rename(columns={'passengers': 'dependent_var'}, inplace=True)

# Check the result
timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dependent_var  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %% [markdown]
# ## 2. EDA
#
# ### 2.1. Baseline model performance
#
# Let's set a quick performance baseline using a quick/easy linear regression model.

# %%
# Your code here! Hint use a numeric range equal to the length of the dataset for x.
# Instantiate a linear model
linear_model=LinearRegression()

# Generate a uniform x variabel representing the time steps
x=np.array(range(len(timeseries_df))).reshape(-1, 1)

# Fit the model
fit_result=linear_model.fit(x, timeseries_df['dependent_var'])

# Make predictions over the input domain
predictions=linear_model.predict(x)

# Add the linear model predictions back to the dataframe
timeseries_df['Linear model']=predictions

# Calcualte the root mean squared error
rmse=sqrt(mean_squared_error(timeseries_df['dependent_var'], predictions))

# Save the result for later
rmse_results={'Linear model': rmse}

# Display the result for the user
print(f'Root mean square error: {rmse:.1f}')
# Out:
# Root mean square error: 45.7

# %% [markdown]
# ### 2.2. Missing, and/or extreme values

# %%
# Plot data as a historgram as you normaly would for any numerical data
plt.title('Distribution of dependent variable')
plt.hist(timeseries_df['dependent_var'])
plt.xlabel('Dependent variable')
plt.ylabel('Count')
plt.show()

# %%
timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dependent_var  144 non-null    int64
#  1   Linear model   144 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 3.4 KB

# %%
timeseries_df.describe()
# Out:
#        dependent_var  Linear model
# count     144.000000    144.000000
# mean      280.298611    280.298611
# std       119.966317    110.839929
# min       104.000000     90.309962
# 25%       180.000000    185.304286
# 50%       265.500000    280.298611
# 75%       360.500000    375.292936
# max       622.000000    470.287261

# %% [markdown]
# ### 2.3. Timeseries analysis
#
# Let's now take a look at the data as a timeseries. There are a couple of things to look out for here.
#
# 1. Is the time axis regular - i.e. are the rows evenly spaced in time.
# 2. Is the data stationary - i.e. is there a consistent trend over time. The answer to this question will effect how we model the data.
# 3. Are there regular or cyclical trends - e.g. sales are high on Mondays and low on weekends.

# %% [markdown]
# ### 2.3.1. Plot the time-series
#
# Let's include predictions from the baseline model too and see what we are working with.

# %%
# Plot the data over time and include the linear regression from above
plt.title('Time series analysis: raw data')
plt.plot(timeseries_df['dependent_var'], label='Data')
plt.plot(timeseries_df['Linear model'], label='Linear model')
plt.xlabel('Date')
plt.ylabel('Dependent variable')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3.2. Missing timepoints

# %% [markdown]
# Next, do a quick check to see if the datetime index we just created is evenly spaced - i.e. the time delta between the rows is always the same.

# %%
# Your code here. Hint: take a look and Panda's .resample()
# Take the difference across the datetime index
diff=np.diff(timeseries_df.index.to_numpy())

# Check that all of the differences are equal
equaly_spaced=np.all(diff==diff[0])

print(f'Datetime axis is regular: {equaly_spaced}')

# If the datetime axis not regular - resample it and fill in the missing timepoints with interpolation
if equaly_spaced == False:

    # Resample down to days first
    resampled_timeseries_df=timeseries_df.resample('D').interpolate()

    # Then resample back up to months
    resampled_timeseries_df=resampled_timeseries_df.resample('M').interpolate()
    resampled_timeseries_df.info()

    # Plot the results to be sure we diden't deform anything too badly...
    plt.title('Time series analysis: resampled vs raw data')
    plt.scatter(timeseries_df.index, timeseries_df['dependent_var'], label='Raw data', color='orange')
    plt.plot(resampled_timeseries_df.index, resampled_timeseries_df['dependent_var'], label='Resampled data')
    plt.xlabel('Date')
    plt.ylabel('Dependent variable')
    plt.legend(loc='upper left')
    plt.tight_layout()
    plt.show()

    timeseries_df=resampled_timeseries_df
# Out:
# Datetime axis is regular: False
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-31 to 1960-12-31
# Freq: ME
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dependent_var  144 non-null    float64
#  1   Linear model   144 non-null    float64
# dtypes: float64(2)
# memory usage: 3.4 KB
# /tmp/ipykernel_7784/2366625674.py:17: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled_timeseries_df=resampled_timeseries_df.resample('M').interpolate()

# %% [markdown]
# ### 2.3.3. Stationarity

# %%
# Note: you want to be aware of this property of your data, but you may or may not have to do anything with this information right away!
dftest=adfuller(timeseries_df['dependent_var'], autolag = "AIC")
print(f'Dicky-Fuller p-value: {dftest[1]:.3f}')
# Out:
# Dicky-Fuller p-value: 0.984

# %% [markdown]
# ### 2.3.4. Seasonality

# %%
# Note: you want to be aware of this property of your data, but you may or may not have to do anything with this information right away!
stationary_timeseries_df=timeseries_df['dependent_var'].diff().dropna()

plt.title('Time series analysis: differenced vs raw data')
plt.plot(timeseries_df.index, timeseries_df['dependent_var'], label='Resampled data', color='orange')
plt.plot(stationary_timeseries_df.index, stationary_timeseries_df, label='Differenced data')
plt.xlabel('Date')
plt.ylabel('Dependent variable')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Model training

# %%
# Hint use the 'auto_arima()' function from pmdarima as describe in the reading on 4Geeks.
timeseries_model=auto_arima(timeseries_df['dependent_var'], seasonal=True, stationary=False, trace=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=1012.628, Time=0.93 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1021.005, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1012.917, Time=0.08 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1013.833, Time=0.12 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=1012.119, Time=0.54 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=1011.298, Time=0.19 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=1011.809, Time=0.61 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=1016.507, Time=0.11 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=1016.547, Time=0.11 sec
#  ARIMA(3,1,2)(0,1,0)[12]             : AIC=inf, Time=0.45 sec
#  ARIMA(2,1,3)(0,1,0)[12]             : AIC=1012.999, Time=0.34 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=1014.559, Time=0.06 sec
#  ARIMA(1,1,3)(0,1,0)[12]             : AIC=1010.846, Time=0.25 sec
#  ARIMA(1,1,3)(1,1,0)[12]             : AIC=1010.976, Time=0.39 sec
#  ARIMA(1,1,3)(0,1,1)[12]             : AIC=1011.283, Time=0.47 sec
#  ARIMA(1,1,3)(1,1,1)[12]             : AIC=1012.211, Time=0.85 sec
#  ARIMA(0,1,3)(0,1,0)[12]             : AIC=1012.390, Time=0.07 sec
#  ARIMA(1,1,4)(0,1,0)[12]             : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=1015.209, Time=0.06 sec
#  ARIMA(0,1,4)(0,1,0)[12]             : AIC=1012.747, Time=0.12 sec
#  ARIMA(2,1,4)(0,1,0)[12]             : AIC=1014.936, Time=0.35 sec
#  ARIMA(1,1,3)(0,1,0)[12] intercept   : AIC=inf, Time=0.45 sec
#
# Best model:  ARIMA(1,1,3)(0,1,0)[12]
# Total fit time: 7.059 seconds

# %% [markdown]
# ## 4. Model evaluation
#
# This result *looks* convincing, at least if you don't look too close - but how well are we actualy doing? We need to implement test-train splitting and/or cross-validation to estimate the actual performance on unseen data!
#
# Breaking up time-series data is a little bit harder than other types of tabular data - we can't just randomly select data points for the training and/or validation sets becuase the order matters!
#
# Luckily, Scikit-learn can help us out here - take a look at [TimeSeriesSplit](https://scikit-learn.org/dev/modules/generated/sklearn.model_selection.TimeSeriesSplit.html).

# %%
# I'll leave it up to you to try and figure out a good way to evalueate this model!
forecast=timeseries_model.predict(12)

plt.title('Time series analysis forecast')
plt.plot(timeseries_df['dependent_var'], label='Data')
plt.plot(forecast, label='ARIMA forecast')
plt.xlabel('Timepoint')
plt.ylabel('Dependent variable')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Get the last 12 timepoints from the real data
true_data=timeseries_df['dependent_var'][-12:]

# Plot them against the predictions
plt.scatter(true_data, forecast)
plt.xlabel('Last 12 true values')
plt.ylabel('Next 12 forecasted values')
plt.show()

# %%
# Make predictions for the next 120 timepoints into the future
forecast=timeseries_model.predict(120)

plt.title('Time series analysis forecast')
plt.plot(timeseries_df['dependent_var'], label='Data')
plt.plot(forecast, label='Forecast')
plt.xlabel('Timepoint')
plt.ylabel('Dependent variable')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Set a forecast horizon, i.e. how far into the future, we want to predict
forecast_horizon=6

# Set a model order, i.e. how many past datapoints should be used as input for prediction
model_order=36

# %% [markdown]
# ### 4.1: Test-train Split

# %%
# Make the test set one forecast horizon in length
testing_dataset_size=forecast_horizon

# Calculate how long the training set needs to be
training_set_size=len(timeseries_df) - testing_dataset_size

# Get the training and testing sets
training_data=timeseries_df[:training_set_size]
testing_data=timeseries_df[training_set_size:]

# %% [markdown]
# ### 4.2: Cross Validation

# %%
# Number of 'cross-validation' folds to run
folds=6

# Holders to collect data for later
validation_rmse_values=[]
predicted_values=[]
validation_values=[]

# Set-up a multiplot for the results
fig, axs=plt.subplots(3, 2, figsize=(10,6))
axs=axs.flatten()

# Instantiate a time series splitter
timeseries_splits=TimeSeriesSplit(n_splits=folds, max_train_size=model_order, test_size=forecast_horizon)

# Loop on the splits with a counter
for i, timeseries_split in enumerate(timeseries_splits.split(training_data)):

    # Recover the split indicies
    training_indicies=timeseries_split[0]
    validation_indicies=timeseries_split[1]

    # Get the data for this split from the training data
    fold_training_data=training_data.iloc[training_indicies, :]
    fold_validation_data=training_data.iloc[validation_indicies, :]

    # Fit the model and predict out to the forecast horizon
    timeseries_model=auto_arima(fold_training_data['dependent_var'], stationary=False, trace=True, seasonal=True, m=12, suppress_warnings=True)
    forecast=timeseries_model.predict(forecast_horizon)

    # Collect intermediate results
    predicted_values.extend(forecast)
    validation_values.extend(fold_validation_data['dependent_var'])

    rmse=sqrt(mean_squared_error(fold_validation_data['dependent_var'], forecast))
    validation_rmse_values.append(rmse)

    # Draw the timeseries plot for this fold
    axs[i].set_title(f'Time series: fold {i}')
    axs[i].plot(fold_training_data['dependent_var'], label='Training data')
    axs[i].plot(fold_validation_data['dependent_var'], label='Validation data')
    axs[i].plot(forecast, label='Predictions', color='red')
    axs[i].set_xlabel('Timepoint')
    axs[i].set_ylabel('Dependent variable')
    axs[i].legend(loc='best')

plt.tight_layout()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=175.674, Time=0.61 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=178.796, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=171.344, Time=0.15 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=175.555, Time=0.07 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=251.740, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=170.231, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=171.392, Time=0.11 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=173.265, Time=0.44 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=171.868, Time=0.09 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=171.995, Time=0.07 sec
#  ARIMA(0,0,1)(0,1,0)[12] intercept   : AIC=173.796, Time=0.03 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=173.827, Time=0.13 sec
#  ARIMA(1,0,0)(0,1,0)[12]             : AIC=176.232, Time=0.01 sec
#
# Best model:  ARIMA(1,0,0)(0,1,0)[12] intercept
# Total fit time: 1.797 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=184.633, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=166.349, Time=0.15 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=250.434, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=171.524, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=181.018, Time=0.16 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=168.346, Time=0.27 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=168.347, Time=0.25 sec
#  ARIMA(0,0,1)(1,1,0)[12] intercept   : AIC=172.929, Time=0.20 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(1,0,0)(1,1,0)[12]             : AIC=168.782, Time=0.05 sec
#
# Best model:  ARIMA(1,0,0)(1,1,0)[12] intercept
# Total fit time: 3.776 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=203.786, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=176.063, Time=0.12 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=241.781, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=176.043, Time=0.04 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=175.792, Time=0.07 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=205.661, Time=0.04 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=176.075, Time=0.09 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=176.959, Time=0.10 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=174.508, Time=0.24 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=172.787, Time=0.12 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=176.548, Time=0.05 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=174.982, Time=0.04 sec
#  ARIMA(3,0,1)(0,1,0)[12] intercept   : AIC=174.002, Time=0.12 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(3,0,0)(0,1,0)[12] intercept   : AIC=172.747, Time=0.07 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=174.516, Time=0.19 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=174.363, Time=0.12 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(4,0,0)(0,1,0)[12] intercept   : AIC=174.579, Time=0.13 sec
#  ARIMA(4,0,1)(0,1,0)[12] intercept   : AIC=175.939, Time=0.28 sec
#  ARIMA(3,0,0)(0,1,0)[12]             : AIC=178.033, Time=0.05 sec
#
# Best model:  ARIMA(3,0,0)(0,1,0)[12] intercept
# Total fit time: 5.313 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=0.58 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=180.664, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=183.235, Time=0.04 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=183.237, Time=0.05 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=181.755, Time=0.03 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=181.755, Time=0.03 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=183.755, Time=0.05 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=182.269, Time=0.02 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=182.280, Time=0.03 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=184.269, Time=0.04 sec
#  ARIMA(0,1,0)(0,1,0)[12] intercept   : AIC=182.657, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,1,0)[12]
# Total fit time: 0.931 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=213.170, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=198.213, Time=0.09 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=206.741, Time=0.09 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=238.160, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=196.265, Time=0.04 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=198.221, Time=0.09 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=200.026, Time=0.33 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=198.128, Time=0.06 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=198.183, Time=0.05 sec
#  ARIMA(0,0,1)(0,1,0)[12] intercept   : AIC=205.070, Time=0.04 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=199.851, Time=0.07 sec
#  ARIMA(1,0,0)(0,1,0)[12]             : AIC=197.650, Time=0.02 sec
#
# Best model:  ARIMA(1,0,0)(0,1,0)[12] intercept
# Total fit time: 1.554 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=195.572, Time=0.50 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=186.328, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=187.760, Time=0.06 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=187.792, Time=0.06 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=187.278, Time=0.03 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=187.278, Time=0.03 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=189.278, Time=0.05 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=186.494, Time=0.02 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=186.599, Time=0.02 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=188.488, Time=0.04 sec
#  ARIMA(0,1,0)(0,1,0)[12] intercept   : AIC=187.930, Time=0.01 sec
#
# Best model:  ARIMA(0,1,0)(0,1,0)[12]
# Total fit time: 0.851 seconds

# %%
# Plot the forcasted values against the true values
plt.title('Cross-validation: predicted vs actual value')
plt.scatter(validation_values, predicted_values)
plt.xlabel('True value')
plt.ylabel('Predicted value')
plt.show()

# %%
print(f'Cross validation RMSE: {np.mean(validation_rmse_values):.1f}+/-{np.std(validation_rmse_values):.1f}')
rmse_results['ARIMA cross-validation mean']=np.mean(validation_rmse_values)
# Out:
# Cross validation RMSE: 22.8+/-9.1

# %% [markdown]
# ### 4.3: Model Evaluation

# %%
timeseries_model=auto_arima(training_data['dependent_var'], stationary=False, seasonal=True, trace=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=1.06 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=969.238, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=961.838, Time=0.06 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=962.689, Time=0.11 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=961.254, Time=0.03 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=962.205, Time=0.11 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.86 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=963.026, Time=0.06 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=962.740, Time=0.06 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=961.930, Time=0.03 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=964.709, Time=0.09 sec
#  ARIMA(1,1,0)(0,1,0)[12] intercept   : AIC=962.832, Time=0.05 sec
#
# Best model:  ARIMA(1,1,0)(0,1,0)[12]
# Total fit time: 2.598 seconds

# %%
# Make predictions
forecast=timeseries_model.predict(forecast_horizon)

# Plot the result
fig, (ax1, ax2)=plt.subplots(1,2, figsize=(10,4))

ax1.set_title('Time series')
ax1.plot(testing_data['dependent_var'], label='Testing data')
ax1.plot(forecast, label='Predictions')
ax1.set_xlabel('Timepoint')
ax1.set_ylabel('Dependent variable')
ax1.legend(loc='best')

ax2.set_title('Predicted vs actual')
ax2.scatter(testing_data['dependent_var'], forecast)
ax2.set_xlabel('Actual value')
ax2.set_ylabel('Predicted value')

plt.tight_layout()
plt.show()

# %%
# Calculate RMSE on test set
rmse=sqrt(mean_squared_error(testing_data['dependent_var'], forecast))
rmse_results['ARIMA test data']=rmse

print(f'Root mean square error:')

for experiment, rmse in rmse_results.items():
    print(f'  {experiment}: {rmse:.1f}')
# Out:
# Root mean square error:
#   Linear model: 45.7
#   ARIMA cross-validation mean: 22.8
#   ARIMA test data: 37.8
